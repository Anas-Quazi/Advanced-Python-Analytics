# %%
import pandas as pd

# %%
#! load from datsets
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')

dataset['train'].to_pandas()

# %%
#* read csv data
df = pd.read_csv('C:/Users/anasq/OneDrive/Desktop/Advance_Python/Datasets/Football_Analysis.csv')

# %%
#^ data inspection

#? first and last
df.head()
df.tail()

#& statistics % info
df.shape
df.info()
df.describe()

# %%
#* accessing rows nd columns

#~ specific columns
df[['club', 'formation']].head(16)

#~ specific rows
df.iloc[15:20]

#& specific rows + colums
df.iloc[:8, 0:4]
df[['club', 'playing_style']].iloc[16:25]

# %%
#^ more inspection (on rows/colms)...

df.playing_style.unique()
df[(df.playing_style == 'Defensive') & (df.xG > 55)]
